# %% [markdown]
# <a href="https://colab.research.google.com/github/teddy-teem/deep-learning/blob/master/autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %% [markdown]
# ![Screenshot 2025-07-04 at 18.28.07.png](data:image/png;base64,...)

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %% [markdown]
# New more complex
# ![Screenshot 2025-07-04 at 18.36.07.png](data:image/png;base64,...)

# %%
x = torch.tensor(3.0, requires_grad=True)

# %%
y = x**2

# %%
z = torch.sin(y)

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %% [markdown]
# ![Screenshot 2025-07-04 at 18.35.54.png](data:image/png;base64,...)

# %%
x = torch.tensor(6.7)  # Input features
y = torch.tensor(0.0) # Output labels

w = torch.tensor(1.0, requires_grad=True) # Weights
b = torch.tensor(0.0, requires_grad=True) # Bias

# %%
def binary_cross_entropy(prediction, target):
    epsilon = 1e-7
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
z = w * x + b
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy(y_pred, y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)

# %%
y = (x**2).mean()

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])
